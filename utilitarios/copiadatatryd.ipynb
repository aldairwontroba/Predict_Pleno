# %%
import os
import shutil
from datetime import datetime
from pathlib import Path

# Caminhos de origem e destino

ano = 2018
base = Path(r"E:\Mercado BMF&BOVESPA\tryd") / str(ano)
origem = base / "Extraidos INDWIN"   # ajuste aqui se tiver acento: "Extraídos WININD"
# origem = base / "Extraidos DOLWDO"

# destino = r"C:\Tryd7\workspace\replay\import\WDO&DOL"
destino = r"C:\Tryd7\workspace\replay\import\WIN&IND"

# Data limite
data_limite = datetime.strptime(f"{ano}-01-01", "%Y-%m-%d")

if not base.exists():
    raise FileNotFoundError(f"A pasta base não existe: {base}")

# Percorre todas as subpastas
for pasta in os.listdir(origem):
    caminho_pasta = os.path.join(origem, pasta)
    
    if os.path.isdir(caminho_pasta):
        try:
            # Tenta converter o nome da pasta em data
            data_pasta = datetime.strptime(pasta, "%Y-%m-%d")
            
            if data_pasta > data_limite:
                print(f"Copiando arquivos da pasta: {pasta}")
                # Copia todos os arquivos dentro da pasta
                for arquivo in os.listdir(caminho_pasta):
                    caminho_arquivo = os.path.join(caminho_pasta, arquivo)
                    if os.path.isfile(caminho_arquivo):
                        shutil.copy2(caminho_arquivo, destino)
        except ValueError:
            # Caso a pasta não tenha nome de data, ignora
            pass

print("✅ Cópia concluída!")
# Out:
# Copiando arquivos da pasta: 2018-04-11
# Copiando arquivos da pasta: 2018-04-12
# Copiando arquivos da pasta: 2018-04-13
# Copiando arquivos da pasta: 2018-04-16
# Copiando arquivos da pasta: 2018-04-17
# Copiando arquivos da pasta: 2018-04-18
# Copiando arquivos da pasta: 2018-04-19
# Copiando arquivos da pasta: 2018-04-20
# Copiando arquivos da pasta: 2018-04-23
# Copiando arquivos da pasta: 2018-04-24
# Copiando arquivos da pasta: 2018-04-25
# Copiando arquivos da pasta: 2018-04-26
# Copiando arquivos da pasta: 2018-04-27
# Copiando arquivos da pasta: 2018-04-30
# Copiando arquivos da pasta: 2018-05-02
# Copiando arquivos da pasta: 2018-05-03
# Copiando arquivos da pasta: 2018-05-04
# Copiando arquivos da pasta: 2018-05-07
# Copiando arquivos da pasta: 2018-05-08
# Copiando arquivos da pasta: 2018-05-09
# Copiando arquivos da pasta: 2018-05-10
# Copiando arquivos da pasta: 2018-05-11
# Copiando arquivos da pasta: 2018-05-14
# Copiando arquivos da pasta: 2018-05-15
# Copiando arquivos da pasta: 2018-05-16
# Copiando arquivos da pasta: 2018-05-17
# Copiando arquivos da pasta: 2018-05-18
# Copiando arquivos da pasta: 2018-05-21
# Copiando arquivos da pasta: 2018-05-22
# Copiando arquivos da pasta: 2018-05-23
# Copiando arquivos da pasta: 2018-05-24
# Copiando arquivos da pasta: 2018-05-25
# Copiando arquivos da pasta: 2018-05-28
# Copiando arquivos da pasta: 2018-05-29
# Copiando arquivos da pasta: 2018-05-30
# Copiando arquivos da pasta: 2018-06-01
# Copiando arquivos da pasta: 2018-06-04
# Copiando arquivos da pasta: 2018-06-05
# Copiando arquivos da pasta: 2018-06-06
# Copiando arquivos da pasta: 2018-06-07
# Copiando arquivos da pasta: 2018-06-08
